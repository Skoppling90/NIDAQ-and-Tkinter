# %%
import nidaqmx
import pprint

with nidaqmx.Task() as task:
    task.ai_channels.add_ai_voltage_chan("Dev1/ai0")
    data=task.read(number_of_samples_per_channel=1000)
    task.timing.cfg_samp_clk_timing(1000)
    pp.pprint(data)
# Out:
# ---------------------------------------------------------------------------
# DaqError                                  Traceback (most recent call last)
# <ipython-input-2-6d25d28ad84a> in <module>()
#       3
#       4 with nidaqmx.Task() as task:
# ----> 5     task.ai_channels.add_ai_voltage_chan("Dev1/ai0")
#       6     data=task.read(number_of_samples_per_channel=1000)
#       7     task.timing.cfg_samp_clk_timing(1000)
#
# ~\Anaconda3\lib\site-packages\nidaqmx\_task_modules\ai_channel_collection.py in add_ai_voltage_chan(self, physical_channel, name_to_assign_to_channel, terminal_config, min_val, max_val, units, custom_scale_name)
#    2561             terminal_config.value, min_val, max_val, units.value,
#    2562             custom_scale_name)
# -> 2563         check_for_error(error_code)
#    2564
#    2565         return self._create_chan(physical_channel, name_to_assign_to_channel)
#
# ~\Anaconda3\lib\site-packages\nidaqmx\errors.py in check_for_error(error_code)
#     125         cfunc(error_buffer, 2048)
#     126
# --> 127         raise DaqError(error_buffer.value.decode("utf-8"), error_code)
#     128
#     129     elif error_code > 0:
#
# DaqError: Device cannot be accessed.  Possible causes:
#
# Device is no longer present in the system.
# Device is not powered.
# Device is powered, but was temporarily without power.
# Device and/or chassis driver support may have been removed.
# Device is damaged.
#
# Ensure the device is properly connected and turned on. Ensure the device and/or chassis is supported in the current version of the driver. Check the device's status in NI MAX. Turn the computer off and on again. If you suspect that the device is damaged, contact National Instruments at ni.com/support.
# Device Specified: Dev1
#
# Task Name: _unnamedTask<0>
#
# Status Code: -201003

# %%
import matplotlib.pyplot as plt

plt.plot(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-21ec6df3f84c> in <module>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.plot(data)
#
# NameError: name 'data' is not defined

# %%
import nidaqmx
from nidaqmx.system import local

system = nidaqmx.System.local()
print('DAQmx {0}.{1}.{2}'.format(system.major_version, system.minor_version,
                                 system.update_version))

for device in system.devices:
    print('Device Name: {0}, Product Category: {1}, Product Type: {2}'.format(
        device.name, device.product_category, device.product_type))

# %%
import tkinter as tk
root = tk.Tk()
geometry = tk.Canvas(root, width=800, height=600)
label = tk.Label(root, text="Hello World", padx=10, pady=10)
scale = tk.Scale(root, from_=0, to=100)
label.pack()
scale.pack()
geometry.pack()

root.mainloop()
